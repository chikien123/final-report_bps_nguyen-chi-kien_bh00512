# %% [markdown]
# <a href="https://colab.research.google.com/github/chikien123/final-report_bps_nguyen-chi-kien_bh00512/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install pandas

# %%
import pandas as pd

df = pd.read_csv('supermarket_sales .csv')
print(df.info())
numeric_cols = df.select_dtypes(include='number').columns
df[numeric_cols] = df[numeric_cols].fillna(df[numeric_cols].mean())
non_numeric_cols = df.select_dtypes(exclude='number').columns
df[non_numeric_cols] = df[non_numeric_cols].fillna('Unknown')
df.drop_duplicates(inplace=True)
df['Invoice ID'] = df['Branch'].str.lower()
df.to_csv('supermarket_sales .csv', index=False)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 17 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Invoice ID               1000 non-null   object
#  1   Branch                   1000 non-null   object
#  2   City                     1000 non-null   object
#  3   Customer type            1000 non-null   object
#  4   Gender                   1000 non-null   object
#  5   Product line             1000 non-null   object
#  6   Unit price               1000 non-null   float64
#  7   Quantity                 1000 non-null   int64
#  8   Tax 5%                   1000 non-null   float64
#  9   Total                    1000 non-null   float64
#  10  Date                     1000 non-null   object
#  11  Time                     1000 non-null   object
#  12  Payment                  1000 non-null   object
#  13  cogs                     1000 non-null   float64
# ...

# %%
pip install matplotlib

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('supermarket_sales.csv')
plt.figure(figsize=(10, 6))
plt.plot([1, 2, 3], [4, 5, 6])
plt.title('Example Plot')
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('supermarket_sales.csv')

plt.figure(figsize=(25, 5))
plt.scatter(df['Quantity'], df['Tax 5%'], color='purple', alpha=0.6)
plt.xlabel('Quantity Sold')
plt.ylabel('Tax')
plt.title('Tax vs. Quantity Sold')
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Read the CSV file
df = pd.read_csv('supermarket_sales.csv')
market_trends = df['Customer type'].value_counts()
plt.figure(figsize=(20, 5))
plt.pie(market_trends, labels=market_trends.index, autopct='%1.1f%%', colors=['yellow', 'red'])
plt.title('Customer type')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Read the CSV file
df = pd.read_csv('supermarket_sales.csv')
plt.figure(figsize=(30, 5))
plt.hist(df['Unit price'], bins=20, color='yellow', edgecolor='black')
plt.xlabel('Unit Price (in USD)')
plt.ylabel('Payment')
plt.title('Unit price')
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Read the CSV file
df = pd.read_csv('supermarket_sales.csv')

# Select the top 30 countries (assuming your DataFrame has this data)
top_30_countries = df.head(30)  # Adjust this to 30 if needed
plt.figure(figsize=(25, 9))

# Assuming 'CountryName' and 'GDP' are columns in your DataFrame
plt.bar(top_30_countries['Invoice ID'], top_30_countries['City'], color='blue')
plt.xlabel('Invoice ID')
plt.ylabel('City')
plt.title('Top 30 Countries by City')
plt.xticks(rotation=45, ha='right')
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.preprocessing import StandardScaler
data = pd.read_csv('supermarket_sales.csv')
print(data.columns)
feature_columns = ['Unit price', 'Quantity']
target_column = 'Total'
missing_columns = [col for col in feature_columns if col not in data.columns]
if missing_columns:
    raise KeyError(f"Missing columns: {', '.join(missing_columns)}")
features = data[feature_columns]
target = data[target_column]
scaler = StandardScaler()
scaled_features = scaler.fit_transform(features)
X_train, X_test, y_train, y_test = train_test_split(scaled_features, target, test_size=0.2, random_state=42)
model = LinearRegression()
model.fit(X_train, y_train)
y_pred = model.predict(X_test)
print(f"Mean Squared Error: {mean_squared_error(y_test, y_pred)}")
print(f"R-squared: {r2_score(y_test, y_pred)}")
# Out:
# Index(['Invoice ID', 'Branch', 'City', 'Customer type', 'Gender',
#        'Product line', 'Unit price', 'Quantity', 'Tax 5%', 'Total', 'Date',
#        'Time', 'Payment', 'cogs', 'gross margin percentage', 'gross income',
#        'Rating'],
#       dtype='object')
# Mean Squared Error: 6228.045510688691
# R-squared: 0.9042708171993606

# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression
data = pd.read_csv('supermarket_sales.csv')
feature_columns = ['Unit price', 'Quantity']
target_column = 'Total'
features = data[feature_columns]
target = data[target_column]
scaler = StandardScaler()
scaled_features = scaler.fit_transform(features)
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(scaled_features, target, test_size=0.2, random_state=42)
model = LinearRegression()
model.fit(X_train, y_train)
from sklearn.metrics import mean_squared_error, r2_score
y_pred = model.predict(X_test)

print(f"Mean Squared Error: {mean_squared_error(y_test, y_pred)}")
print(f"R-squared: {r2_score(y_test, y_pred)}")
future_data = pd.DataFrame({'Unit price': [50000], 'Quantity': [10]})
scaled_future_data = scaler.transform(future_data)
future_sales_prediction = model.predict(scaled_future_data)
print(f"Predicted Sales for marketing spend 50000 and number of salespeople 10: {future_sales_prediction[0]}")
# Out:
# Mean Squared Error: 6228.045510688691
# R-squared: 0.9042708171993606
# Predicted Sales for marketing spend 50000 and number of salespeople 10: 290158.155581496

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
model = LinearRegression()
model.fit(X_train, y_train)
y_pred = model.predict(X_test)
print(f"Mean Squared Error: {mean_squared_error(y_test, y_pred)}")
print(f"R-squared: {r2_score(y_test, y_pred)}")
# Out:
# Mean Squared Error: 6228.045510688691
# R-squared: 0.9042708171993606

# %%
pip install rpy2

# %%
import rpy2.robjects as ro

# Define R code
r_code = """
dataset <- data.frame(x = rnorm(100), y = rnorm(100))
model <- lm(y ~ x, data = dataset)
summary(model)
"""

# Run the R code
ro.r(r_code)
# Out:
# <rpy2.robjects.vectors.ListVector object at 0x7c4c7e797000> [RTYPES.VECSXP]
# R classes: ('summary.lm',)
# [LangSexpV..., LangSexpV..., FloatSexp..., FloatSexp..., ..., FloatSexp..., FloatSexp..., FloatSexp..., FloatSexp...]
#   call: <class 'rpy2.robjects.language.LangVector'>
#   Rlang( lm(formula = y ~ x, data = dataset) )
#   terms: <class 'rpy2.robjects.Formula'>
#   <rpy2.robjects.Formula object at 0x7c4c70547f40> [RTYPES.LANGSXP]
# R classes: ('terms', 'formula')
#   residuals: <class 'rpy2.robjects.vectors.FloatVector'>
#   <rpy2.robjects.vectors.FloatVector object at 0x7c4c70547600> [RTYPES.REALSXP]
# R classes: ('numeric',)
# [-0.422547, 0.040613, -1.759718, -0.370003, ..., -1.582488, -0.048729, -0.286194, -0.171713]
#   coefficients: <class 'rpy2.robjects.vectors.FloatMatrix'>
#   <rpy2.robjects.vectors.FloatMatrix object at 0x7c4c7e7bfb00> [RTYPES.REALSXP]
# R classes: ('matrix', 'array')
# ...

# %%
import matplotlib.pyplot as plt

x = [1, 2, 3, 4, 5]  # Replace with your data
y = [2, 3, 5, 7, 11]  # Replace with your data

plt.plot(x, y)
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.title('Line Chart')
plt.show()
